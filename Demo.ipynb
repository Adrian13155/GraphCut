# %%
# !pip install felzenszwalb-segmentation

# %%
import numpy as np
from glob import glob
from PIL import Image
from matplotlib import pyplot as plt
from felzenszwalb_segmentation import segment

# %%
image_files = glob('img/output.png')
len(image_files)
# Out:
# 1

# %%
image = np.array(Image.open(image_files[0]))
segmented_image = segment(image, 0.2, 400, 50)
fig = plt.figure(figsize=(12, 12))
a = fig.add_subplot(1, 2, 1)
plt.imshow(image)
a = fig.add_subplot(1, 2, 2)
plt.imshow(segmented_image.astype(np.uint8))
plt.show()
# Out:
# /PublicData/xmm/project/graghCut/felzenszwalb_segmentation/felzenszwalb_segmentation/utils/filter_utils.py:14: RuntimeWarning: overflow encountered in scalar add
#   src[y, max(x - i, 0)] + src[y, min(x + i, width - 1)])

# %%
image = np.array(Image.open(image_files[0]))
segmented_image = segment(image, 0.2, 400, 50)
fig = plt.figure(figsize=(12, 12))
a = fig.add_subplot(1, 2, 1)
plt.imshow(image)
a = fig.add_subplot(1, 2, 2)
plt.imshow(segmented_image.astype(np.uint8))
plt.show()
# Out:
# /content/felzenszwalb_segmentation/felzenszwalb_segmentation/utils/filter_utils.py:14: RuntimeWarning: overflow encountered in ubyte_scalars
#   src[y, max(x - i, 0)] + src[y, min(x + i, width - 1)])

# %%
image = np.array(Image.open(image_files[100]))
segmented_image = segment(image, 0.2, 400, 50)
fig = plt.figure(figsize=(12, 12))
a = fig.add_subplot(1, 2, 1)
plt.imshow(image)
a = fig.add_subplot(1, 2, 2)
plt.imshow(segmented_image.astype(np.uint8))
plt.show()
# Out:
# /content/felzenszwalb_segmentation/felzenszwalb_segmentation/utils/filter_utils.py:14: RuntimeWarning: overflow encountered in ubyte_scalars
#   src[y, max(x - i, 0)] + src[y, min(x + i, width - 1)])

# %%
image = np.array(Image.open(image_files[50]))
segmented_image = segment(image, 0.1, 400, 50)
fig = plt.figure(figsize=(12, 12))
a = fig.add_subplot(1, 2, 1)
plt.imshow(image)
a = fig.add_subplot(1, 2, 2)
plt.imshow(segmented_image.astype(np.uint8))
plt.show()
# Out:
# /content/felzenszwalb_segmentation/felzenszwalb_segmentation/utils/filter_utils.py:14: RuntimeWarning: overflow encountered in ubyte_scalars
#   src[y, max(x - i, 0)] + src[y, min(x + i, width - 1)])
